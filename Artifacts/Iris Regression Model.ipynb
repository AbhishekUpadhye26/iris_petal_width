# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import pickle as pkl

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris_1 = pd.DataFrame(iris.data,columns = iris.feature_names)
iris_2 = pd.Series(iris.target)

# %%
columns = iris.feature_names + ["species"]

# %%
df = pd.concat([iris_1,iris_2],axis=1)
df.columns = columns
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# ...

# %%
X = df.drop("petal width (cm)",axis=1)
y = df["petal width (cm)"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
reg_model = LinearRegression()

# %%
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg_model.score(X_train,y_train)
# Out:
# 0.9504997847901151

# %%
y_pred_train = reg_model.predict(X_train)

# %%
train_score = r2_score(y_train,y_pred_train)

# %%
train_score
# Out:
# 0.9504997847901151

# %%
y_pred_test = reg_model.predict(X_test)

# %%
test_score = r2_score(y_test,y_pred_test)
test_score
# Out:
# 0.9528645949793247

# %%
reg_model.score(X_test,y_test)
# Out:
# 0.9528645949793247

# %%
pkl.dump(reg_model,open("iris_reg_model.pkl",'wb'))

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'iris_reg_model.pkl', 'Untitled.ipynb']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X_test.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'species'],
#       dtype='object')

# %%
df["species"].dtypes
# Out:
# dtype('int32')

# %%
df.to_dict(orient='records')
# Out:
# [{'sepal length (cm)': 5.1,
#   'sepal width (cm)': 3.5,
#   'petal length (cm)': 1.4,
#   'petal width (cm)': 0.2,
#   'species': 0},
#  {'sepal length (cm)': 4.9,
#   'sepal width (cm)': 3.0,
#   'petal length (cm)': 1.4,
#   'petal width (cm)': 0.2,
#   'species': 0},
#  {'sepal length (cm)': 4.7,
#   'sepal width (cm)': 3.2,
#   'petal length (cm)': 1.3,
#   'petal width (cm)': 0.2,
#   'species': 0},
#  {'sepal length (cm)': 4.6,
#   'sepal width (cm)': 3.1,
#   'petal length (cm)': 1.5,
#   'petal width (cm)': 0.2,
#   'species': 0},
#  {'sepal length (cm)': 5.0,
#   'sepal width (cm)': 3.6,
#   'petal length (cm)': 1.4,
#   'petal width (cm)': 0.2,
#   'species': 0},
#  {'sepal length (cm)': 5.4,
#   'sepal width (cm)': 3.9,
#   'petal length (cm)': 1.7,
#   'petal width (cm)': 0.4,
#   'species': 0},
#  {'sepal length (cm)': 4.6,
#   'sepal width (cm)': 3.4,
#   'petal length (cm)': 1.4,
#   'petal width (cm)': 0.3,
#   'species': 0},
#  {'sepal length (cm)': 5.0,
# ...

# %%
d = {'sepal length (cm)': 5.1,
  'sepal width (cm)': 3.5,
  'petal length (cm)': 1.4,
  'species': 0}

# %%
test_df = pd.DataFrame(d,index=[0])

# %%
reg_model.predict(test_df)[0]==0.23395956740866475
# Out:
# True
